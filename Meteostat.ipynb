# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielterceiro/Meteostat/blob/main/Meteostat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Meteostat
# Using python's library meteostat to get the weather data from Santos/SP

# %%
# !pip install meteostat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# %%
# Set time period
start = datetime(2021, 1, 1)
end = datetime(2022, 10, 16)

# %%
# Create Point for Santos, SP
location = Point(-23.9694, -46.3353)

# %%
# Get daily data for 2018
data = Daily(location, start, end)
data = data.fetch()

# %%
# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmax', 'tmin'])
plt.show()
